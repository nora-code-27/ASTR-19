# %%
import numpy as np

# %% [markdown]
# The method defineSinX has the imput x, which can be an int or float, and will return the sin() of the input x in radians

# %%
def defineSinX(x):
    sinX = np.sin(x)
    return sinX

# %% [markdown]
# The method defineCosX has the imput x, which can be an int or float, and will return the cos() of the input x in radians

# %%
def defineCosX(x):
    cosX = np.cos(x)
    return cosX

# %% [markdown]
# The method tabulate has no inputs. It creates an array with 1000 itterations of an x-value itterating between 0 and 2pi. It then uses the defineSinX and defineCosX methods to create seperate arrays with every entry either being the sin(x) or the cos(x). It then prints a table so that every x, sin(x), and cos(x) value are arranged in seperate collums, with each sin(x) and cos(x) alligned with its corrosponding x-value.

# %%
def tabulate():
    print("  x      sin(x)   cos(x)")
    pi = np.pi
    pi = pi * 2
    sinArray = []
    cosArray = []
    x = np.linspace(0,pi,1000)
    for i in range(1000):
        xIn = x[i]
        sinNew = defineSinX(xIn)
        sinArray.append(sinNew)
    for i in range(1000):
        xIn2 = x[i]
        cosNew = defineCosX(xIn2)
        cosArray.append(cosNew)
    for i in range(1000):
        cosXNew = cosArray[i]
        sinXNew = sinArray[i]
        xAgain = x[i]
        print(f"{xAgain:5.4f} | {sinXNew:5.4f} | {cosXNew:5.4f}")
def main():
    a = tabulate()
    
if __name__ == "__main__":
    main()
# Out:
#   x      sin(x)   cos(x)
# 0.0000 | 0.0000 | 1.0000
# 0.0063 | 0.0063 | 1.0000
# 0.0126 | 0.0126 | 0.9999
# 0.0189 | 0.0189 | 0.9998
# 0.0252 | 0.0252 | 0.9997
# 0.0314 | 0.0314 | 0.9995
# 0.0377 | 0.0377 | 0.9993
# 0.0440 | 0.0440 | 0.9990
# 0.0503 | 0.0503 | 0.9987
# 0.0566 | 0.0566 | 0.9984
# 0.0629 | 0.0629 | 0.9980
# 0.0692 | 0.0691 | 0.9976
# 0.0755 | 0.0754 | 0.9972
# 0.0818 | 0.0817 | 0.9967
# 0.0881 | 0.0879 | 0.9961
# 0.0943 | 0.0942 | 0.9956
# 0.1006 | 0.1005 | 0.9949
# 0.1069 | 0.1067 | 0.9943
# 0.1132 | 0.1130 | 0.9936
# 0.1195 | 0.1192 | 0.9929
# 0.1258 | 0.1255 | 0.9921
# 0.1321 | 0.1317 | 0.9913
# 0.1384 | 0.1379 | 0.9904
# 0.1447 | 0.1442 | 0.9896
# 0.1509 | 0.1504 | 0.9886
# 0.1572 | 0.1566 | 0.9877
# 0.1635 | 0.1628 | 0.9867
# 0.1698 | 0.1690 | 0.9856
# 0.1761 | 0.1752 | 0.9845
# 0.1824 | 0.1814 | 0.9834
# 0.1887 | 0.1876 | 0.9823
# 0.1950 | 0.1937 | 0.9811
# 0.2013 | 0.1999 | 0.9798
# 0.2076 | 0.2061 | 0.9785
# 0.2138 | 0.2122 | 0.9772
# 0.2201 | 0.2184 | 0.9759
# ...

# %% [markdown]
# The method tabulateSet has one input "iterations". It creates an array with 1000 itterations of an x-value itterating between 0 and 2pi. It then uses the defineSinX and defineCosX to create seperate arrays that find the respective sin() and cos() for the first n-terms in the array of x-values, where the amount of n-terms is defined by the input iterations. It then prints a table so that the first n-terms of x, sin(x), and cos(x) value are arranged in seperate collums, with each sin(x) and cos(x) alligned with its corrosponding x-value.

# %%
def tabulateSet(iterations):
    print("  x      sin(x)   cos(x)")
    pi = np.pi
    pi = pi * 2
    sinArray = []
    cosArray = []
    x = np.linspace(0,pi,1000)
    for i in range(1000):
        xIn = x[i]
        sinNew = defineSinX(xIn)
        sinArray.append(sinNew)
    for i in range(iterations):
        xIn2 = x[i]
        cosNew = defineCosX(xIn2)
        cosArray.append(cosNew)
    for i in range(iterations):
        cosXNew = cosArray[i]
        sinXNew = sinArray[i]
        xAgain = x[i]
        print(f"{xAgain:5.4f} | {sinXNew:5.4f} | {cosXNew:5.4f}")
def main():
    b = tabulateSet(10)
if __name__ == "__main__":
    main()
# Out:
#   x      sin(x)   cos(x)
# 0.0000 | 0.0000 | 1.0000
# 0.0063 | 0.0063 | 1.0000
# 0.0126 | 0.0126 | 0.9999
# 0.0189 | 0.0189 | 0.9998
# 0.0252 | 0.0252 | 0.9997
# 0.0314 | 0.0314 | 0.9995
# 0.0377 | 0.0377 | 0.9993
# 0.0440 | 0.0440 | 0.9990
# 0.0503 | 0.0503 | 0.9987
# 0.0566 | 0.0566 | 0.9984
